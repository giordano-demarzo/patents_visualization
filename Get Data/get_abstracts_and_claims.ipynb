# %% [markdown]
# Importing the necessary libraries

# %%
from epo.tipdata.epab import EPABClient
import os
import numpy as np
import pandas as pd
import re

# %% [markdown]
# Defining two functions to make readable the abstracts and claims

# %%
def extract_texts(claims):
    return [claim['text'] for claim in claims if 'text' in claim]
def remove_brackets(text):
    if isinstance(text, list):
        return [re.sub(r'<.*?>', '', item) for item in text]
    elif isinstance(text, str):
        return re.sub(r'<.*?>', '', text)
    return text

# %%
# turn env='PROD' for full data
epab = EPABClient(env = 'TEST')

# %% [markdown]
# The following code creates folders named with the year considered in the for loop and stores inside the folder all the abstracts and claims of each publication in .txt files

# %%
q = epab.query_abstract_language("en")
#counter = 0
for year in range(2006,2024):
    #creating directory related to the current year
    new_folder_path = str(year)
    os.makedirs(new_folder_path, exist_ok=True)
    output_folder = new_folder_path
    
    p = epab.query_publication_date(str(year)+"%")
    s = q & p
    # s represents the data with abstracts in english and in the current year
    
    df = s.get_results("title.en,publication,ipc,abstract.text,claims",output_type="dataframe")
    df['abstract.text'] = df['abstract.text'].apply(remove_brackets)
    for _, row in df.iterrows():
        pub_number = row['publication.number']
        #check that the rows 'claims' and 'abstract.text' are non empty elements
        if(row['claims'] and row['abstract.text']):
    # Define the filenames for abstract and claims
            abstract_filename = os.path.join(output_folder, f'{pub_number}_abstract.txt')
            claims_filename = os.path.join(output_folder, f'{pub_number}_claims.txt')
            abstract = row['abstract.text']
            claims = row['claims'][0]['text']
            claims_ = remove_brackets(claims)
            #print(row['claims'])
            with open(claims_filename, 'w') as claims_file:
                claims_file.write(claims_)
    # Write the abstract content to a text file
            with open(abstract_filename, 'w') as abstract_file:
                abstract_file.write(row['abstract.text'])

# %% [markdown]
# If needed we can also put everything into a dataframe (year,publication_number,title,ipc,abstract,claims)

# %%
# choose the language of the abstracts
q = epab.query_abstract_language("en")
# select the publication period
p = epab.query_publication_date("20060101-20231231")
#get the intersection between both q and p hence s contains all the publication in english in the period 2006-2023
s = q & p
# define the dataframe
df = s.get_results("title.en,publication,ipc,abstract.text,claims",output_type="dataframe")
#make the abstract column readable
df['abstract.text'] = df['abstract.text'].apply(remove_brackets)
#make the claims column readable
df['claims'] = df['claims'].apply(extract_texts)
df['claims'] = df['claims'].apply(remove_brackets)
#take only the rows in which claims are present
df = df[df['claims'].apply(lambda x: len(x) > 0)].reset_index(drop=True)
df['claims'] = df['claims'].apply(lambda x: x[0])
#delete other columns with not needed informations
df = df.drop(columns=['publication.country','publication.kind','publication.language'])
#transform each element of the IPC column a list of IPC codes
df['ipc'] = df['ipc'].apply(lambda x: [item['symbol'] for item in x])
# Save DataFrame as a zipped CSV file
csv_file_in_zip = '2006_2023_all_data.csv'
df.to_csv('2006_2023_all_data.zip', index=False, compression=dict(method='zip', archive_name=csv_file_in_zip))

# %%
df
# Out:
#                                              title.en publication.number  \
# 0   CONTROL DEVICE FOR A TORQUE CONVERTER IN AN AU...            0006943
# 1          Physiologically adaptive cardiac pacemaker            0007189
# 2   Improved electrode array and method of making ...            0007157
# 3                                    Decorative panel            0006848
# 4   Process for the preparation of cyclopropane de...            0007154
# 5                        Fuel injection pump assembly            0007799
# 6                           AUTOMATIC FOCUSING SYSTEM            0007902
# 7                                       Fluid bearing            0007409
# 8                      Flexible container for liquids            0007685
# 9                       Sheet material cutting device            0007523
# 10  Skin treatment compositions, process for their...            0007785
# 11   Label positioning mechanism for printing machine            0008306
# 12                                   ANTI-TUMOR AGENT            0008573
# 13                             Down-draft carburettor            0008499
# 14  3-Chloro-6-hydroxy-5-methylbenzoic acid deriva...            0009636
# 15  Pharmaceutical preparations containing a mollu...            0010061
# 16                   PROCESS FOR PRODUCING TABLE SALT            0009506
# 17                             Surgical safety device            0009893
# 18  Cyclopentenone and cyclopentenol derivatives a...            0009892
# 19     Phenolic esteramide antioxidants and their use            0009866
# 20          Improvements in or relating to valve bags            0010563
# 21  METHOD OF AND APPARATUS FOR FABRICATING PILE F...            0010546
# 22       Countercurrent contact process and apparatus            0011870
# 23                                      DELAY CIRCUIT            0011647
# 24  Track for sliding closure and mechanism compri...            0012511
# 25  Apparatus for detecting and locating the posit...            0012580
# 26  A method of moulding shaped articles and an ap...            0012589
# 27  An electro-mechanical transducer for use in a ...            0012136
# 28  Method for determining human chorionic gonadot...            0013032
# 29  Processes for preparation of beta-lactam compo...            0014567
# 30                                    CORRUGATED HOSE            0014217
# 31  Method for separating plastics and metal from ...            0014289
# 32  Polymer, preparation and formulations for prep...            0015761
# 33                          Method of cleaning metals            0015336
# 34  Unsaturated macrocyclic ketones; their prepara...            0015412
# 35      DEVICE FOR REMOTE CONTROL OF HYDRAULIC CRANES            0015296
# 36             Cutting torch height control apparatus            0016466
# 37  Unspun strand break-out device, spinning machi...            0016512
# 38                     CHARGING GENERATOR CONTROLLERS            0016228
# 39            Method for the operation of a fuel cell            0018693
# 40  Improvements in or relating to electric fence ...            0018849
# 41            TURBINE-TYPE INTERNAL COMBUSTION ENGINE            0018411
# 42                                     Sitting device            0018812
# 43  A closed-circuit magnetohydrodynamic (MHD) sys...            0018822
# 44                            Reflex reflector device            0018798
# 45  Method and apparatus for non-destructive testi...            0018747
# 46  EXHAUST GAS CLEANING SYSTEM FOR A DIESEL ENGIN...            0019635
# 47  Building elements and method of constructing a...            0020014
#
#    publication.date                                                ipc  \
# 0          19800123                                        [F16H45/02]
# 1          19800123                                         [A61N1/36]
# 2          19800123                                        [A61F11/04]
# 3          19800123          [B44C5/04, B44F7/00, E04F13/00, B05D5/06]
# 4          19800123                           [C07C120/00, C07C121/48]
# 5          19800206                                        [F02M59/04]
# 6          19800206                     [G11B7/08, G11B7/12, G02B7/11]
# 7          19800206                                        [F16C32/06]
# 8          19800206        [B65D53/08, B65B7/02, B65D85/72, B65D30/24]
# 9          19800206                                        [B23D27/02]
# 10         19800206                                         [A61K7/48]
# 11         19800305                              [B65C9/18, B65C11/02]
# 12         19800305                           [C07D311/72, A61K31/355]
# 13         19800305                                         [F02M9/10]
# 14         19800416  [C07D493/20, C12P17/18, A61K31/35, C12R1/465, ...
# 15         19800416  [A61K35/60, A61K45/06, A61K45/06, A61K35:60, A...
# 16         19800416                               [C01D3/06, C01D3/16]
# 17         19800416                                        [A61M25/02]
# 18         19800416  [C07C35/06, C07C49/703, C07C49/707, C07C49/597...
# 19         19800416  [C07C103/38, C07C103/78, C07C149/23, C08K5/20,...
# 20         19800514                                        [B65D30/24]
# 21         19800514                             [D06C23/04, D06C27/00]
# 22         19800611                    [B01J47/10, B01J8/20, C02F1/42]
# 23         19800611  [H03K5/13, H03K5/01, H03K17/28, H03J5/00, H03L...
# 24         19800625                              [E05D15/10, B60J5/06]
# 25         19800625                                         [F41J5/06]
# 26         19800625  [B29J1/00, B29C3/00, B29D3/02, B28B13/02, C04B...
# 27         19800625                              [G08B21/00, A61B5/10]
# 28         19800709                                        [G01N33/76]
# 29         19800820  [C07D501/02, C07D501/59, C07D501/16, C07D501/1...
# 30         19800820                                        [F16L11/11]
# 31         19800820                                         [B03B9/06]
# 32         19800917          [C08G8/18, C08G8/22, C09J3/16, C07C65/05]
# 33         19800917                               [C23G5/02, C23F7/10]
# 34         19800917  [C07C49/587, C07C49/385, C07C45/72, C07C45/67,...
# 35         19800917                  [F15B11/04, F15B11/16, B66C13/12]
# 36         19801001                                         [B23K7/10]
# 37         19801001                                        [D01H13/16]
# 38         19801001                               [H02J7/24, G05F1/10]
# 39         19801112                                         [H01M8/04]
# 40         19801112                                         [H05C1/04]
# 41         19801112                                         [F02C5/12]
# 42         19801112         [A47C9/00, B60N1/00, B63B29/04, B61D33/00]
# 43         19801112                                        [H02K44/08]
# 44         19801112                                        [G02B5/122]
# 45         19801112                                        [G01N29/04]
# 46         19801210  [F01N3/02, F01N3/10, F01N3/20, B01D53/34, F23J...
# 47         19801210  [E04B2/28, E04C2/34, E04C2/46, E04C2/06, E04B2...
#
#                                         abstract.text  \
# 0   In an automatic transmission for a vehicle in ...
# 1   A cardiac pacemaker is disclosed having means ...
# 2   An electrode array 10 specifically for implant...
# 3   A base coated substrate carries a pattern defi...
# 4   Compounds of formula:\nwherein both groups X a...
# 5   A fuel injection pump assembly includes a sing...
# 6   An automatic focusing system to focus automati...
# 7   A fluid bearing for rotatably supporting a rot...
# 8   A flexible container (1) for liquids in which ...
# 9   A generally portable sheet material cutting to...
# 10   A cosmetically acceptable composition for top...
# 11  A label positioning mechanism for use with a p...
# 12  An anti-tumor agent with low toxicity and a hi...
# 13  A variable venturi down-draft carburettor comp...
# 14  3-Chloro-6-hydroxy-5-methylbenzoic acid deriva...
# 15  The invention concerns novel pharmaceutical pr...
# 16  A process for efficiently producing common sal...
# 17  A surgical safety device to be fixed externall...
# 18  Compounds of the general formula I are disclos...
# 19  A phenolic esteramide, useful in protecting or...
# 20  A valve bag has a valve opening in which a val...
# 21  A method and an apparatus for suede-finishing ...
# 22  The invention concerns a process for contactin...
# 23  A delay circuit comprising counter circuits (3...
# 24  A track assembly for a sliding closure member ...
# 25  An apparatus for detecting a projectile, and f...
# 26  articles sucn as corrugated sheets are manufac...
# 27  An electro-mechanical transducer suitable for ...
# 28  A method of determining human chorionic gonado...
# 29  Kinetically controlled triaryl phosphite halog...
# 30  In orderto permit a corrugated hose to maintai...
# 31  Plastics material metallized with a magnetical...
# 32  A polymer containing carboxylate groups which ...
# 33  Ferrous metal parts are prepared for painting ...
# 34  Uaturated ketones of formula\npossessing two s...
# 35  A device for remote control of a hydraulic cra...
# 36  An apparatus (10) for controlling the height o...
# 37  A strand break-out device for preventing the f...
# 38  To improve the thermal resistance, thermal sho...
# 39  An improved method for operating a fuel cell w...
# 40  An electricfence energiser (1) including contr...
# 41  Internal combustion engine combinating a two-c...
# 42  A sitting device (1,2) for freely chosen or fi...
# 43  The production of electrical power by means of...
# 44  The reflectivity of a reflex reflector device ...
# 45  A tyre inspecting apparatus includes a frame (...
# 46  A device for purifying the exhaust gas of a di...
# 47  A moulded building sheet (1) has opposed side ...
#
#                                                claims
# 0   1. A control device for a torque converter in ...
# 1   1. A physiologically adaptive cardiac pacemake...
# 2   1. An electrode array comprising a flexible bi...
# 3   1. In a decorative panel comprising a pigmente...
# 4   1. A process for the preparation of a compound...
# 5   1. A plunger type fuel injection pump assembly...
# 6   1) An automatic focusing apparatus which compr...
# 7   1. A fluid bearing for rotatably supporting a ...
# 8   1. A flexible container for liquids, the conta...
# 9   1. Apparatus for cutting sheet material compri...
# 10  1. A cosmetically acceptable composition for t...
# 11  1. A label positioning mechanism for use with ...
# 12  1. An antitumor agent, characterized by contai...
# 13  1. A down-draft carburettor comprising a downw...
# 14  1. A 3-chloro-6-hydroxy-5-methylbenzoic acid d...
# 15  1. A pharmaceutical preparation for oral admin...
# 16  1. A method of manufacturing table salt, compr...
# 17  1. A surgical safety device to be fixed extern...
# 18  1. Compounds of the general formula I :wherein...
# 19  1. An esteramide characterised in that it has ...
# 20  1. A valve bag having a valve opening in which...
# 21  1. A process for preparing a suede-like raised...
# 22  1. A process for continuous countercurrent con...
# 23  1. A delay circuit comprising a counter for co...
# 24  1. A track assembly for a sliding closure memb...
# 25  1. An apparatus for detecting and locating the...
# 26  1. A method of making shaped articles from a d...
# 27  1. An electro-mechanical transducer suitable f...
# 28  1. A method of determining human chorionic gon...
# 29  1. A process for preparing penicillin or cepha...
# 30  1. A folding hose H formed in a bellows type a...
# 31  1. A method for separation of metal and plasti...
# 32  1. A polymer containing'carboxylate groups cha...
# 33  1. A method in which metal articles are spraye...
# 34  1. An unsaturated macrocyclic ketone of formul...
# 35  1. A remote-control device for hydraulic crane...
# 36  1. An apparatus (10) for controlling the dista...
# 37  1. A strand break-out device for prevention of...
# 38  1. A charging generator control device for cha...
# 39  1. Method for the operation of a fuel cell wit...
# 40  1. An electric fence energiser capable of supp...
# 41  1. In an apparatus including a rotary wheel ha...
# 42  1. A sitting device (1,2) to be mounted on a s...
# 43  1. A method for producing electrical power by ...
# 44  1. A reflex reflector device comprising a firs...
# 45  1. A non-destructive tire testing apparatus co...
# 46  1. An exhaust gas cleaning system for diesel e...
# 47  1. A moulded building sheet characterised by i...
